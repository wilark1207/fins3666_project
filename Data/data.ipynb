# %% [markdown]
# ## Intraday OHLCV data (shared for all three ideas)

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta

symbol = "SPY"
interval = "1m"
periods = ["7d"] # yfinance only allows 7 days per request

data_all = []

# rolling download for multiple months (approx 7 days per pull)
for i in range(0, 300): # about 300*7 = 2100 days = 3 years
    end_date = datetime.today() - timedelta(days=i*7)
    start_date = end_date - timedelta(days=7)
    df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
    if not df.empty:
        df.reset_index(inplace=True)
        data_all.append(df)

df_all = pd.concat(data_all)
df_all.drop_duplicate(subsets="Datetime", inplace=True)
df_all.rename(columns={"Datetime": "timestamp_utc"}, inplace=True)
df_all.to_csv("data/SPY_intraday_2022_2025.csv", index=False)
print("Saved data/SPY_intraday_2022_2025.csv", len(df_all))
# Out:
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025-10-04 03:14:44.419286 -> 2025-10-11 03:14:44.419286) (Yahoo error = "1m data not available for startTime=1759562084 and endTime=1760166884. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025-09-27 03:14:45.138790 -> 2025-10-04 03:14:45.138790) (Yahoo error = "1m data not available for startTime=1758957285 and endTime=1759562085. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025-09-20 03:14:45.978883 -> 2025-09-27 03:14:45.978883) (Yahoo error = "1m data not available for startTime=1758352485 and endTime=1758957285. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025-09-13 03:14:46.672265 -> 2025-09-20 03:14:46.672265) (Yahoo error = "1m data not available for startTime=1757747686 and endTime=1758352486. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025-09-06 03:14:47.636534 -> 2025-09-13 03:14:47.636534) (Yahoo error = "1m data not available for startTime=1757142887 and endTime=1757747687. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025-08-30 03:14:48.289262 -> 2025-09-06 03:14:48.289262) (Yahoo error = "1m data not available for startTime=1756538088 and endTime=1757142888. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025-08-23 03:14:48.889697 -> 2025-08-30 03:14:48.889697) (Yahoo error = "1m data not available for startTime=1755933288 and endTime=1756538088. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025-08-16 03:14:49.560659 -> 2025-08-23 03:14:49.560659) (Yahoo error = "1m data not available for startTime=1755328489 and endTime=1755933289. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025-08-09 03:14:50.191060 -> 2025-08-16 03:14:50.191060) (Yahoo error = "1m data not available for startTime=1754723690 and endTime=1755328490. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025-08-02 03:14:50.831542 -> 2025-08-09 03:14:50.831542) (Yahoo error = "1m data not available for startTime=1754118890 and endTime=1754723690. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025-07-26 03:14:51.417295 -> 2025-08-02 03:14:51.417295) (Yahoo error = "1m data not available for startTime=1753514091 and endTime=1754118891. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025-07-19 03:14:52.046826 -> 2025-07-26 03:14:52.046826) (Yahoo error = "1m data not available for startTime=1752909292 and endTime=1753514092. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025-07-12 03:14:53.031388 -> 2025-07-19 03:14:53.031388) (Yahoo error = "1m data not available for startTime=1752304493 and endTime=1752909293. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025-07-05 03:14:53.758427 -> 2025-07-12 03:14:53.758427) (Yahoo error = "1m data not available for startTime=1751699693 and endTime=1752304493. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025-06-28 03:14:54.400801 -> 2025-07-05 03:14:54.400801) (Yahoo error = "1m data not available for startTime=1751094894 and endTime=1751699694. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025-06-21 03:14:55.232849 -> 2025-06-28 03:14:55.232849) (Yahoo error = "1m data not available for startTime=1750490095 and endTime=1751094895. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025-06-14 03:14:55.828498 -> 2025-06-21 03:14:55.828498) (Yahoo error = "1m data not available for startTime=1749885295 and endTime=1750490095. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2025
The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2021-08-21 03:17:37.128233 -> 2021-08-28 03:17:37.128233) (Yahoo error = "1m data not available for startTime=1629530257 and endTime=1630135057. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2021-08-14 03:17:38.190686 -> 2021-08-21 03:17:38.190686) (Yahoo error = "1m data not available for startTime=1628925458 and endTime=1629530258. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2021-08-07 03:17:39.132711 -> 2021-08-14 03:17:39.132711) (Yahoo error = "1m data not available for startTime=1628320659 and endTime=1628925459. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2021-07-31 03:17:39.906649 -> 2021-08-07 03:17:39.906649) (Yahoo error = "1m data not available for startTime=1627715859 and endTime=1628320659. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2021-07-24 03:17:41.683919 -> 2021-07-31 03:17:41.683919) (Yahoo error = "1m data not available for startTime=1627111061 and endTime=1627715861. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2021-07-17 03:17:43.538158 -> 2021-07-24 03:17:43.538158) (Yahoo error = "1m data not available for startTime=1626506263 and endTime=1627111063. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2021-07-10 03:17:44.901019 -> 2021-07-17 03:17:44.901019) (Yahoo error = "1m data not available for startTime=1625901464 and endTime=1626506264. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2021-07-03 03:17:45.952544 -> 2021-07-10 03:17:45.952544) (Yahoo error = "1m data not available for startTime=1625296665 and endTime=1625901465. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2021-06-26 03:17:46.758733 -> 2021-07-03 03:17:46.758733) (Yahoo error = "1m data not available for startTime=1624691866 and endTime=1625296666. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2021-06-19 03:17:47.667752 -> 2021-06-26 03:17:47.667752) (Yahoo error = "1m data not available for startTime=1624087067 and endTime=1624691867. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2021-06-12 03:17:48.605576 -> 2021-06-19 03:17:48.605576) (Yahoo error = "1m data not available for startTime=1623482268 and endTime=1624087068. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2021-06-05 03:17:49.641766 -> 2021-06-12 03:17:49.641766) (Yahoo error = "1m data not available for startTime=1622877469 and endTime=1623482269. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2021-05-29 03:17:50.537316 -> 2021-06-05 03:17:50.537316) (Yahoo error = "1m data not available for startTime=1622272670 and endTime=1622877470. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2021-05-22 03:17:51.686876 -> 2021-05-29 03:17:51.686876) (Yahoo error = "1m data not available for startTime=1621667871 and endTime=1622272671. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2021-05-15 03:17:52.935182 -> 2021-05-22 03:17:52.935182) (Yahoo error = "1m data not available for startTime=1621063072 and endTime=1621667872. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2021-05-08 03:17:54.016272 -> 2021-05-15 03:17:54.016272) (Yahoo error = "1m data not available for startTime=1620458274 and endTime=1621063074. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1m 2021-05-01 03:17:55.049292 -> 2021-05-08 03:17:55.049292) (Yahoo error = "1m data not available for startTime=1619853475 and endTime=1620458275. The requested range must be within the last 30 days.")')
# /var/folders/hp/kfy3hmy15mn6824slvj7zgd40000gn/T/ipykernel_28667/3405748827.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 15
#      13 end_date = datetime.today() - timedelta(days=i*7)
#      14 start_date = end_date - timedelta(days=7)
# ---> 15 df = yf.download(symbol, start=start_date, end=end_date, interval=interval)
#      16 if not df.empty:
#      17     df.reset_index(inplace=True)
#
# File ~/Documents/FINS3666/assignment-3/.venv/lib/python3.13/site-packages/yfinance/utils.py:92, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      89 logger.debug(f'Entering {func.__name__}()')
#      91 with IndentationContext():
# ---> 92     result = func(*args, **kwargs)
#      94 logger.debug(f'Exiting {func.__name__}()')
#      95 return result
#
# File ~/Documents/FINS3666/assignment-3/.venv/lib/python3.13/site-packages/yfinance/multi.py:167, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, interval, prepost, proxy, rounding, timeout, session, multi_level_index)
#     160         _download_one_threaded(ticker, period=period, interval=interval,
#     161                                start=start, end=end, prepost=prepost,
#     162                                actions=actions, auto_adjust=auto_adjust,
#     163                                back_adjust=back_adjust, repair=repair, keepna=keepna,
#     164                                progress=(progress and i > 0),
#     165                                rounding=rounding, timeout=timeout)
#     166     while len(shared._DFS) < len(tickers):
# --> 167         _time.sleep(0.01)
#     168 # download synchronously
#     169 else:
#     170     for i, ticker in enumerate(tickers):
#
# KeyboardInterrupt:

# %% [markdown]
# polygon.io OHLCV data 2024-2025

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
from tqdm import tqdm
import time

API_KEY = "aIT4pyAR2rUApDm8ivkT6BqWpiSQTl8R"
TICKER = "SPY"
MULTIPLIER = 1
TIMESPAN = "minute"
START_DATE = "2022-01-01"
END_DATE = "2023-12-31"

def fetch_agg(ticker, start, end):
    url = f"https://api.polygon.io/v2/aggs/ticker/{ticker}/range/{MULTIPLIER}/{TIMESPAN}/{start}/{end}"
    params = {
        "adjusted": "true",
        "sort": "asc",
        "limit": 50000,
        "apiKey": API_KEY
    }
    r = requests.get(url, params=params)
    if r.status_code != 200:
        print("Error:", r.status_code, r.text)
        return None
    data = r.json().get("results", [])
    if not data:
        return None
    df = pd.DataFrame(data)
    df["timestamp_utc"] = pd.to_datetime(df["t"], unit="ms", utc=True)
    df = df.rename(columns={
        "o": "open",
        "h": "high",
        "l": "low",
        "c": "close",
        "v": "volume",
        "vw": "vwap"
    })[["timestamp_utc", "open", "high", "low", "close", "volume", "vwap"]]
    return df

# Split by months to stay under API limits
date_ranges = pd.date_range(START_DATE, END_DATE, freq="30D")
dfs = []

for i in tqdm(range(len(date_ranges)-1)):
    start = date_ranges[i].strftime("%Y-%m-%d")
    end = date_ranges[i+1].strftime("%Y-%m-%d")
    df_part = fetch_agg(TICKER, start, end)
    if df_part is not None:
        dfs.append(df_part)
    time.sleep(12)  # avoid rate limit (5 req/min on free tier)

# Merge all
df = pd.concat(dfs).drop_duplicates("timestamp_utc").sort_values("timestamp_utc")
df["ret"] = df["close"].pct_change()
df["vol_5m"] = df["ret"].rolling(5).std()
df["vol_30m"] = df["ret"].rolling(30).std()

# Save clean dataset
df.to_csv(f"{TICKER}_intraday_polygon_2022_2023.csv", index=False)
print(f"✅ Saved {len(df):,} rows to data/{TICKER}_intraday_polygon_2022_2023.csv")
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# Error: 403 {"status":"NOT_AUTHORIZED","request_id":"1675c13855d2aea47fa6109c5e916d84","message":"Your plan doesn't include this data timeframe. Please upgrade your plan at https://polygon.io/pricing"}
#   0%|          | 0/24 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 51
#      49     if df_part is not None:
#      50         dfs.append(df_part)
# ---> 51     time.sleep(12)  # avoid rate limit (5 req/min on free tier)
#      53 # Merge all
#      54 df = pd.concat(dfs).drop_duplicates("timestamp_utc").sort_values("timestamp_utc")
#
# KeyboardInterrupt:
